# %%
import pandas as pd

# %%
df = pd.read_csv('Competitions.csv')

# %%
df['DeadlineDate'] = pd.to_datetime(df['EnabledDate'])
df_by_year = df[df['DeadlineDate'].dt.year >= 2020]

# %%
df_filtered = df_by_year[df_by_year['TotalTeams']>100]
df_filtered
# Out:
#          Id                                 Slug  \
# 1595  13836  cassava-leaf-disease-classification
# 1954  16245         trends-assessment-prediction
# 1968  16295           tweet-sentiment-extraction
# 2250  17722                     11-785-s20-hw1p2
# 2251  17723      11-785-s20-hw2p2-classification
# ...     ...                                  ...
# 5657  61542         llm-detect-ai-generated-text
# 5658  65704                           santa-2023
# 5659  65711               playground-series-s4e1
# 5660  65862          widsdatathon2024-challenge1
# 5661  68479               playground-series-s4e2
#
#                                                 Title  \
# 1595              Cassava Leaf Disease Classification
# 1954                              TReNDS Neuroimaging
# 1968                       Tweet Sentiment Extraction
# 2250           11-785, Spring 2020, Homework 1 Part 2
# 2251      11-785, Spring 2020, HW2P2 - Classification
# ...

# %%
comps = ['Plant Seedlings Classification', 'Cornell Birdcall Identification', 'Instacart Market Basket Analysis', 'iMet Collection 2019 - FGVC6', 'Leaf Classification', 'San Francisco Crime Classification', 'Dog Breed Identification', 'Two Sigma Connect: Rental Listing Inquiries', 'Gendered Pronoun Resolution', 'Spooky Author Identification', 'APTOS 2019 Blindness Detection', 'Prostate cANcer graDe Assessment (PANDA) Challenge', 'PetFinder.my Adoption Prediction', 'Tabular Playground Series - Jan 2021', 'Restaurant Revenue Prediction', 'Tabular Playground Series - Feb 2021', 'New York City Taxi Fare Prediction', 'Google Analytics Customer Revenue Prediction', 'Avito Demand Prediction Challenge', 'Facial Keypoints Detection', 'New York City Taxi Trip Duration', 'Mercari Price Suggestion Challenge', 'Sberbank Russian Housing Market', 'Bike Sharing Demand', 'TMDB Box Office Prediction', 'ASHRAE - Great Energy Predictor III', 'Santander Value Prediction Challenge', 'Recruit Restaurant Visitor Forecasting', 'Bengali.AI Handwritten Grapheme Classification', 'Digit Recognizer', 'Titanic - Machine Learning from Disaster', 'Histopathologic Cancer Detection', 'University of Liverpool - Ion Switching', 'INGV - Volcanic Eruption Prediction', 'Quora Question Pairs', 'Instant Gratification', 'Costa Rican Household Poverty Level Prediction', 'CareerCon 2019 - Help Navigate Robots', 'Binary Classification with a Software Defects Dataset', 'Deepfake Detection Challenge', 'House Prices - Advanced Regression Techniques', 'Natural Language Processing with Disaster Tweets', 'Quora Insincere Questions Classification', 'Mechanisms of Action (MoA) Prediction', 'Santander Customer Transaction Prediction', 'Tweet Sentiment Extraction', 'Cassava Leaf Disease Classification', 'PUBG Finish Placement Prediction (Kernels Only)', 'Kannada MNIST', 'Aerial Cactus Identification', 'Riiid Answer Correctness Prediction', 'SIIM-ISIC Melanoma Classification', 'IEEE-CIS Fraud Detection', 'Global Wheat Detection', 'Predict Future Sales', 'Jigsaw Unintended Bias in Toxicity Classification', 'Jane Street Market Prediction', 'Petals to the Metal - Flower Classification on TPU', 'OSIC Pulmonary Fibrosis Progression', 'Jigsaw Multilingual Toxic Comment Classification', 'Home Credit Default Risk', 'Toxic Comment Classification Challenge', 'LANL Earthquake Prediction', 'Flower Classification with TPUs', 'M5 Forecasting - Accuracy', 'Google QUEST Q&A Labeling', 'Plant Pathology 2020 - FGVC7', 'Generative Dog Images', "What's Cooking? (Kernels Only)", 'Dogs vs. Cats Redux: Kernels Edition', "Don't Overfit! II", 'Categorical Feature Encoding Challenge']
new_comps = ["RANZCR CLiP - Catheter and Line Position Challenge","What's Cooking?","Give Me Some Credit","Ghouls, Goblins, and Ghosts... Boo!","Rainforest Connection Species Audio Detection","Expedia Hotel Recommendations","VinBigData Chest X-ray Abnormalities Detection","Human Protein Atlas - Single Cell Classification","HuBMAP - Hacking the Kidney","Planet: Understanding the Amazon from Space","WSDM - KKBox's Music Recommendation Challenge","Forest Cover Type Prediction","Mercedes-Benz Greener Manufacturing","Aesthetic Visual Analysis","Market Basket - ID NDSC 2020","CSM/SEM6420 workshop","DSNet: fastai Hackathon","EC524: Heart-disease classification","Pneumonia Diagnosis","NTUST: Information Retrieval and Applications","Sarcasmo","PMR3508 - Tarefa 1 - 3508 Adult Dataset","Bad comments","Who is a Friend?","WiDS Datathon 2019","Seleksi Calon Asisten GAIB","IESB Norte - IGM - Maio 2019","hackStat 2.0","2019  ML competition with KISTI","Eval Lab 2 F464","Diabetes Diagnosis","ISSM2020 AI Challenge","DS特論2019年度 演習課題2","Predict the Income - <DECODE> WITH BOARD","OCRV Test Task","Web Enthusiasts' Club NITK Recruitment","Data Champions Android App Malware Prediction","EPAM: Exercise 1 -  Sentiment Analysis","UC Irvine Math 10 Winter 2020","National Data Science Challenge 2019 - Advanced","AI Academy Intermediate Class Competition 1","MLH - Pokemon Challenge","Cloud Faculty Institute Workshop","Predictive Equipment Failures","SQL Saturday Madrid ML Challenge","IA1819","ML in biology","NBA Rookies","DM-Assignment 1","Птица или самолет","Focus start 2020","Predicting Age Groups","[Student] Shopee Code League - Product Detection","ML Hackathon 2019 Q1","[T] PadhAI: Text - Non Text Classification Level 1","[ACM] Recommender System Practice","IESB Sul - IGM - Maio 2019","Tobigs13_7week_competition","COMP 750/850 Project 1","UCI-HAR","Tweet Sentiment Analysis","Fashion MNIST challenge2019","notMNIST Competition","SYDE 522 (Winter 2020)","NCTU BDALAB 2020 Onboard","Night at Cameo","ACM Machine Learning (SVNIT)","UMUC DATA 650 Summer 2019 Competition","Whose line is it anyway?","Oracle Graph ML Contest at Polimi","GirlsGoIT competition 2020","IES Data Mining(WS 18/19)","Python Class - Practice","Test Competition Please Ignore","Digit Classification DL Workshop","DL in NLP Spring 2019. Classification","Sentiment Analysis in Russian","Diabetes Classification","Anokha AI Adept","Digit recognition","ClassificationOFShields","Hackathon Sentimento","Characters classification","Classifying Movie Reviews","Schnell-Mal-Klassifizieren","SERPRO - Iris","YKC-2nd","PadhAI: Text - Non Text Classification Level 4a","MLDM Classification Competition","Hackathon Auto_matic","Fake News e ML","[DM&PR WS19/20] Machine learning competition","Fashion MNIST-ITBA-LAB 2020","finec-1941-hw6","DMA Kaggle Challenge","Fashion MNIST challenge201907","Data-Driven Business Analytics","[DM&PR WS18/19] Machine learning competition","Oxford Fast AI Week 2","Higgs Boson Machine Learning Challenge","West Nile Virus Prediction","Predicting Red Hat Business Value","TalkingData AdTracking Fraud Detection Challenge","Recursion Cellular Image Classification","Open Images 2019 - Object Detection","Humpback Whale Identification Challenge","Northeastern SMILE Lab - Recognizing Faces in the Wild","Airbnb New User Bookings","Airbus Ship Detection Challenge","Categorical Feature Encoding Challenge II","Outbrain Click Prediction","Humpback Whale Identification","Bag of Words Meets Bags of Popcorn","DonorsChoose.org Application Screening","Peking University/Baidu - Autonomous Driving","Facebook V: Predicting Check Ins","Prudential Life Insurance Assessment","Invasive Species Monitoring","RSNA Pneumonia Detection Challenge","TensorFlow 2.0 Question Answering","Two Sigma: Using News to Predict Stock Movements","Coupon Purchase Prediction","Homesite Quote Conversion","Microsoft Malware Prediction","SIIM-ACR Pneumothorax Segmentation","Santander Product Recommendation","Don't Get Kicked!","StumbleUpon Evergreen Classification Challenge","Human Protein Atlas Image Classification","Santander Customer Satisfaction","Sentiment Analysis on Movie Reviews","Contradictory, My Dear Watson","iWildCam 2019 - FGVC6","Influencers in Social Networks","Text classification","[Open] Shopee Code League - Logistics","Brain Cancer Classification","VSB Power Line Fault Detection","Amazon.com - Employee Access Challenge","Abstraction and Reasoning Challenge","Flavours of Physics: Finding τ  →  μμμ","TGS Salt Identification Challenge","Cdiscount’s Image Classification Challenge","Freesound General-Purpose Audio Tagging Challenge","2018 Data Science Bowl","Severstal: Steel Defect Detection","TrackML Particle Tracking Challenge","Liberty Mutual Group: Property Inspection Prediction","COVID-19 diagnostic","Lyft 3D Object Detection for Autonomous Vehicles","Google Landmark Recognition Challenge","IEEE's Signal Processing Society - Camera Model Identification","Ultrasound Nerve Segmentation","Rock, Paper, Scissors","iWildCam 2020 - FGVC7","KNIT_HACKS","Painter by Numbers","Multi-label Bird Species Classification - NIPS 2013","Santa Gift Matching Challenge","Telstra Network Disruptions","Zillow Prize: Zillow’s Home Value Prediction (Zestimate)","BNP Paribas Cardif Claims Management","Predicting a Biological Response","Indoor Location & Navigation","Loan Default Prediction - Imperial College London","University of applied sciences Mannheim","Machine Learning Lab - CAS Data Science FS 20","VSU ML 1 Regression","Used Cars Price Prediction","IESB - 2019","Предсказание положения космических объектов","House pricing","IEEE PES BDC DataThon , Year-2020","Atividade_3_PMR3508","Regression Evaluative Lab","ML 4 Money","Multiple regression for time series data","Basic Regression Competition","SERPRO - Abalone","Predict the missing pixel value v2","compass-canada","ACM Summer'19 Inclass-1","Bike Sharing Demand for Education()","Exam for Students20200129","Team ISTE's Datathon","Machine Learning Lab - CAS Data Science HS 20","House Price Prediction","Fieldguide Challenge: Moths & Butterflies","Tap30 Challenge","Анализ потребительской корзины","Kharagpur Data Analytics Group","Personality Profile Prediction","Einfhrung in Kaggle InClass Competitions</title>","GL Hack: Landmarks","DSI-US-8 Project 2 Regression Challenge","Property price prediction challenge","Задержка рейса самолета","Python for Data science ITEA","Temperature Forecasting","Shelter Animal Outcomes","Elo Merchant Category Recommendation","Lyft Motion Prediction for Autonomous Vehicles","Traveling Santa 2018 - Prime Paths","OpenVaccine: COVID-19 mRNA Vaccine Degradation Prediction","Kobe Bryant Shot Selection","Google Landmark Retrieval 2020","RSNA STR Pulmonary Embolism Detection","Otto Group Product Classification Challenge","COVID19 Global Forecasting (Week 1)","Predicting Molecular Properties","Corporación Favorita Grocery Sales Forecasting","Google Cloud & NCAA® ML Competition 2019-Men's","TalkingData Mobile User Demographics","The Nature Conservancy Fisheries Monitoring","Home Depot Product Search Relevance","PLAsTiCC Astronomical Classification","Grupo Bimbo Inventory Demand","M5 Forecasting - Uncertainty","Statoil/C-CORE Iceberg Classifier Challenge","Walmart Recruiting - Store Sales Forecasting","How Much Did It Rain? II","Nomad2018 Predicting Transparent Conductors","Allstate Claims Severity","Rossmann Store Sales","TReNDS Neuroimaging","Google Cloud & NCAA® ML Competition 2019-Women's","Conway's Reverse Game of Life 2020","I’m Something of a Painter Myself","Google Cloud & NCAA® ML Competition 2020-NCAAM","YKC-cup-1st","I-RICH ML COMPETITION","COVID19 Global Forecasting (Week 3)","COVID19 Global Forecasting (Week 4)","Google Cloud & NCAA® ML Competition 2018-Men's","State Farm Distracted Driver Detection","Click-Through Rate Prediction","Web Traffic Time Series Forecasting","RSNA Intracranial Hemorrhage Detection","WSDM - KKBox's Churn Prediction Challenge","Santa 2019: Revenge of the Accountants","ASN10e Final Submission - Detect COML Faces","DL for exploration geophysics","March Machine Learning Mania 2016","Conway's Reverse Game of Life","COVID19 Global Forecasting (Week 2)"]

# %%
df_new_filtered = df_filtered[~df_filtered['Title'].isin(new_comps)]
df_new_filtered = df_new_filtered[~df_new_filtered['Title'].isin(comps)].reset_index()

# %%
df_new_filtered.to_csv('df_new_filtered.csv')

# %%
df_new_filtered
# Out:
#      index     Id                             Slug  \
# 0     2250  17722                 11-785-s20-hw1p2
# 1     2251  17723  11-785-s20-hw2p2-classification
# 2     2252  17724                 11-785-s20-hw3p2
# 3     2253  17725                 11-785-s20-hw4p2
# 4     2279  17807                 widsdatathon2020
# ..     ...    ...                              ...
# 353   5657  61542     llm-detect-ai-generated-text
# 354   5658  65704                       santa-2023
# 355   5659  65711           playground-series-s4e1
# 356   5660  65862      widsdatathon2024-challenge1
# 357   5661  68479           playground-series-s4e2
#
#                                                Title  \
# 0             11-785, Spring 2020, Homework 1 Part 2
# 1        11-785, Spring 2020, HW2P2 - Classification
# 2             11-785, Spring 2020, Homework 3 Part 2
# 3             11-785, Spring 2020, Homework 4 Part 2
# 4                                 WiDS Datathon 2020
# ...

# %%
import random

# %%
print(df_new_filtered[df_new_filtered['Id']==68479])

# %%
kernels_comps = pd.read_csv('KernelVersionCompetitionSources.csv')
kernels = pd.read_csv('KernelVersions.csv')
kernels_comps.tail()
# Out:
#                Id  KernelVersionId  SourceCompetitionId
# 2444510  71048760        167059633                65711
# 2444511  71048470        167058340                65711
# 2444512  71047785        167055179                65711
# 2444513  71049656        167063371                65711
# 2444514  71048773        167059678                65711

# %%
comps_ids = df_new_filtered['Id'].unique().tolist()
# Out:
# [17722,
#  17723,
#  17724,
#  17725,
#  17807,
#  18005,
#  18011,
#  18233,
#  18423,
#  18455,
#  18458,
#  18459,
#  18461,
#  18627,
#  18631,
#  18632,
#  18807,
#  18808,
#  18809,
#  18810,
#  19175,
#  19231,
#  19396,
#  19548,
#  19884,
#  19991,
#  20085,
#  20439,
#  21100,
#  21424,
#  21723,
#  21819,
#  22040,
#  22359,
#  22378,
#  22414,
#  22415,
#  22416,
#  22422,
#  22754,
#  22757,
#  22759,
#  22760,
#  22804,
#  22881,
#  22930,
#  22931,
#  22936,
#  22962,
#  23103,
#  23110,
#  23166,
#  23249,
#  23341,
#  23367,
#  23382,
#  23415,
#  23457,
#  23486,
#  23548,
#  23549,
#  23550,
#  23637,
#  23652,
#  23661,
#  23684,
#  23764,
#  23847,
#  23945,
#  23946,
#  23985,
#  24026,
#  24105,
#  24142,
#  24235,
#  24245,
#  24263,
#  24280,
#  24286,
#  24373,
#  24464,
#  24539,
#  24540,
#  24563,
#  24652,
#  24764,
#  25123,
#  25191,
#  25226,
#  25347,
#  25348,
#  25349,
#  25383,
#  25401,
#  25563,
#  25608,
#  25612,
#  25613,
#  25657,
#  25722,
# ...

# %%
kernels_comps_filt = kernels_comps[kernels_comps['SourceCompetitionId'].isin(comps_ids)]
kernels_comps_filt

kcf_list = kernels_comps_filt['KernelVersionId'].tolist()

# %%
teams = pd.read_csv('Teams.csv')
teams_memberships = pd.read_csv('TeamMemberships.csv')
# Out:
# /var/folders/zh/dsbs1wbd72z81b85y9td6sx00000gn/T/ipykernel_58711/3409363181.py:1: DtypeWarning: Columns (5,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   teams = pd.read_csv('Teams.csv')

# %%
teams_filt = teams[teams['CompetitionId'].isin(comps_ids)]
teams_filt = teams_filt.dropna(subset=['PublicLeaderboardRank'])
teams_filt
# Out:
#                Id  CompetitionId  TeamLeaderId  \
# 2593659   4085064          17724     3705280.0
# 2680604   4225302          17722     3686984.0
# 2680921   4225886          18233     4298778.0
# 2683319   4230010          18233     4303181.0
# 2684789   4232512          18233     4251292.0
# ...           ...            ...           ...
# 7058195  11705867          68479    16376912.0
# 7058258  11706097          68479    19261177.0
# 7058277  11706186          68479    11402317.0
# 7058284  11706201          68479    19293301.0
# 7058407  11706648          68479    19295802.0
#
#                                                TeamName  \
# 2593659                                   Baseline test
# 2680604                                 Advait Gadhikar
# 2680921                                  Zhongshuai Cao
# 2683319                                         zliu473
# 2684789                                          lyao49
# ...

# %%
teams_list = teams_filt['Id'].unique().tolist()
users = teams_memberships[teams_memberships['TeamId'].isin(teams_list)]
users = users.drop(['Id'], axis=1)
users
# Out:
#            TeamId    UserId RequestDate
# 2984515   4225302   3686984  01/07/2020
# 2984532   4275071   2580781  01/19/2020
# 2984533   4275075   4300303  01/19/2020
# 2984534   4275079   4002435  01/19/2020
# 2984535   4275080   4352576  01/19/2020
# ...           ...       ...         ...
# 7239677  11684456  15867122  02/25/2024
# 7239678  11690380   5080265  02/28/2024
# 7239679  11690380   8706376  02/27/2024
# 7239680  11691411  19170600  02/27/2024
# 7239681  11691850  17492130  02/28/2024
#
# [304662 rows x 3 columns]

# %%
Kernels = pd.read_csv('Kernels.csv')

# %%
Kernels_new = Kernels.dropna(subset=['CurrentKernelVersionId'])
Kernels_new['CurrentKernelVersionId'] = Kernels_new['CurrentKernelVersionId'].astype('int')
Kernels_new_filt = Kernels_new[Kernels_new['CurrentKernelVersionId'].isin(kcf_list)]
kernels_new_filt =pd.merge(Kernels_new, kernels_comps.drop_duplicates(subset=['KernelVersionId']), left_on='CurrentKernelVersionId', right_on='KernelVersionId', how='left')
kernels_new_filt
# Out:
# /var/folders/zh/dsbs1wbd72z81b85y9td6sx00000gn/T/ipykernel_58711/4149960695.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kernels_new['CurrentKernelVersionId'] = Kernels_new['CurrentKernelVersionId'].astype('int')
#             Id_x  AuthorUserId  CurrentKernelVersionId  \
# 0              1          2505                     205
# 1              2          3716                    1748
# 2              4          3716                      41
# 3              5         28963                      19
# 4              6          3716                      21
# ...          ...           ...                     ...
# 968308  52680837      17677665               167064686
# 968309  52681325       5365857               167066024
# ...

# %%
merged_df = pd.merge(teams_filt, users, left_on='Id', right_on='TeamId', how='inner')


kernels_go = kernels_new_filt[['AuthorUserId', 'CurrentKernelVersionId', 'SourceCompetitionId']]

final_df = pd.merge(merged_df, kernels_go, left_on=['UserId', 'CompetitionId'], right_on=['AuthorUserId', 'SourceCompetitionId'], how='inner')

# %%
final_df
# Out:
#              Id  CompetitionId  TeamLeaderId             TeamName  \
# 0       4240714          17807      251000.0        Women Power🇮🇱
# 1       4240714          17807      251000.0        Women Power🇮🇱
# 2       4240714          17807      251000.0        Women Power🇮🇱
# 3       4240714          17807      251000.0        Women Power🇮🇱
# 4       4247708          17807      840811.0             go_green
# ...         ...            ...           ...                  ...
# 37288  11690628          68479    16299075.0       Thamolwan.jaru
# 37289  11690674          68479    12180990.0  DA MATHA Joris Axel
# 37290  11691957          68479     3284256.0    Amanda Kube Jotte
# 37291  11692523          68479     8931408.0    Sourena Khanzadeh
# 37292  11702218          68479     8218415.0            Jay Dixit
#
#        ScoreFirstSubmittedDate LastSubmissionDate  \
# 0                          NaN         02/24/2020
# 1                          NaN         02/24/2020
# ...

# %%
final_df_new = final_df.drop_duplicates(subset=['CurrentKernelVersionId'])
final_df_new = final_df_new.drop_duplicates(subset=['Id'])

# %%
competitions = final_df_new['CompetitionId'].unique().tolist()
filtered_by_rating = pd.DataFrame()

for comp in competitions:
    data = final_df_new[final_df_new['CompetitionId'] == comp]
    temp = data.sort_values('PublicLeaderboardRank', ascending=True).head(10000)
    filtered_by_rating = pd.concat([filtered_by_rating, temp], ignore_index=True)

# %%
filtered_by_rating
# Out:
#              Id  CompetitionId  TeamLeaderId                  TeamName  \
# 0       4249216          17807       18463.0              Prevision.io
# 1       4240714          17807      251000.0             Women Power🇮🇱
# 2       4393925          17807      257832.0                   EPFL 🇨🇭
# 3       4247708          17807      840811.0                  go_green
# 4       4441942          17807     4547744.0                       WOS
# ...         ...            ...           ...                       ...
# 22867  11593623          68479     9230790.0           Eyosias Teffera
# 22868  11636350          68479     7096172.0  SAI LIKITH KUMAR REDDY D
# 22869  11591771          68479     6243364.0       Jaisurya Sundarbabu
# 22870  11650050          68479    16708027.0              Yash Mhaskar
# 22871  11665210          68479    16645747.0       Pravesh Sharma 2002
#
#        ScoreFirstSubmittedDate LastSubmissionDate  \
# 0                          NaN         02/24/2020
# ...

# %%
filtered_by_rating.to_csv('super_kernels2.csv')
